# %% [markdown]
# <a href="https://colab.research.google.com/github/Elisha-Hart/Access-The-String-Using-Slicing-And-Indexing-Assignment/blob/main/Standardize_Data_IRIS_dataset_Scaled_data%2Cetc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("/content/data.zip", encoding_errors = "ignore")

# %%
def data_quality_check(data):
  print("Data Head", data.head())
  print("Data Inconsistency Check", data.dtypes)
  print("Data Null Check", data.isnull().sum())
  print("Data Information Check", data.info())
  print("Data Description Check", data.describe())
  print("Data Tail", data.tail())

# %%
print(data_quality_check(data))
# Out:
# Data Head     Age Cabin Embarked     Fare                                          Name  \
# 0  34.5   NaN        Q   7.8292                              Kelly, Mr. James
# 1  47.0   NaN        S   7.0000              Wilkes, Mrs. James (Ellen Needs)
# 2  62.0   NaN        Q   9.6875                     Myles, Mr. Thomas Francis
# 3  27.0   NaN        S   8.6625                              Wirz, Mr. Albert
# 4  22.0   NaN        S  12.2875  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#    Parch  PassengerId  Pclass     Sex  SibSp  Survived   Ticket Title  \
# 0      0          892       3    male      0       NaN   330911    Mr
# 1      0          893       3  female      1       NaN   363272   Mrs
# 2      0          894       2    male      0       NaN   240276    Mr
# 3      0          895       3    male      0       NaN   315154    Mr
# 4      1          896       3  female      1       NaN  3101298   Mrs
#
#    Family_Size
# 0            0
# 1            1
# 2            0
# ...

# %%
data["Age"].fillna(data["Age"].mean(), inplace = True)
data["Fare"].fillna(data["Fare"].mean(), inplace = True)
data["Cabin"].fillna(data["Cabin"].mode(), inplace = True)

# %%
data.isnull().sum()
# Out:
# Age              0
# Cabin          326
# Embarked         0
# Fare             0
# Name             0
# Parch            0
# PassengerId      0
# Pclass           0
# Sex              0
# SibSp            0
# Survived       418
# Ticket           0
# Title            0
# Family_Size      0
# dtype: int64

# %%
### Train Test Split
### Creating Features and Target
X = data.drop(["Survived"], axis = 1)
y = data["Survived"]

# %%
X
# Out:
#       Age            Cabin Embarked      Fare  \
# 0    34.5  B57 B59 B63 B66        Q    7.8292
# 1    47.0              NaN        S    7.0000
# 2    62.0              NaN        Q    9.6875
# 3    27.0              NaN        S    8.6625
# 4    22.0              NaN        S   12.2875
# ..    ...              ...      ...       ...
# 413  30.0              NaN        S    8.0500
# 414  39.0             C105        C  108.9000
# 415  38.5              NaN        S    7.2500
# 416  30.0              NaN        S    8.0500
# 417   4.0              NaN        C   22.3583
#
#                                              Name  Parch  PassengerId  Pclass  \
# 0                                Kelly, Mr. James      0          892       3
# 1                Wilkes, Mrs. James (Ellen Needs)      0          893       3
# 2                       Myles, Mr. Thomas Francis      0          894       2
# 3                                Wirz, Mr. Albert      0          895       3
# ...

# %%
y
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 413   NaN
# 414   NaN
# 415   NaN
# 416   NaN
# 417   NaN
# Name: Survived, Length: 418, dtype: float64

# %%
X.shape
# Out:
# (418, 13)

# %%
from sklearn.model_selection import train_test_split
X_train , x_test , y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
X_train
# Out:
#       Age    Cabin Embarked      Fare  \
# 207  24.0      NaN        S   10.5000
# 108  30.0      NaN        S    8.7125
# 389   6.0      NaN        S   21.0750
# 184  27.0  B58 B60        C  247.5208
# 156  29.0      C97        S  221.7792
# ..    ...      ...      ...       ...
# 92   27.0      B71        S   52.0000
# 84   30.0      NaN        Q   10.7083
# 280  23.0      NaN        S    8.6625
# 101  27.0      NaN        S   26.0000
# 59   36.0      B61        C  262.3750
#
#                                                   Name  Parch  PassengerId  \
# 207                       Collett, Mr. Sidney C Stuart      0         1099
# 108                   Willer, Mr. Aaron (Abi Weller")"      0         1000
# 389                        Palsson, Master. Paul Folke      1         1281
# 184  Douglas, Mrs. Frederick Charles (Mary Helene B...      1         1076
# 156                                  Bird, Miss. Ellen      0         1048
# ...

# %%
X_train.shape
# Out:
# (334, 13)

# %%
x_test.shape
# Out:
# (84, 13)

# %%
y_train.shape, y_test.shape ### Make sure the numbers match like 334, 84.
# Out:
# ((334,), (84,))

# %%
data.shape
# Out:
# (418, 14)

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.impute import SimpleImputer

# %%
dataset = pd.read_csv('data.zip')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
# splitting the dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
def preprocessing(data):
  # separating numerical and categorical features
  encoder = LabelEncoder()
  scaler = StandardScaler()
  categorical_data, numerical_data = [], []
  for col in data.columns:
    if data[col].dtypes == "object":
      categorical_data.append(col)
      # Encoding the categorical data
      data[col] = encoder.fit_transform(data[col])
    else:
      numerical_data.append(col)
    # Feature Scaling, Applying std or standardization () for all
    scaled_data = scaler.fit_transform(data)

    return scaled_data

# %%
X = data.drop(["Survived"], axis = 1)
y = data["Survived"]

# %%
from sklearn.datasets import load_iris

# %%
from sklearn import preprocessing
data = load_iris()

X_data = data.data
target = data.target

standard = preprocessing.scale(X_data)
print(standard)
# Out:
# [[-9.00681170e-01  1.01900435e+00 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00 -1.31979479e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.38535265e+00  3.28414053e-01 -1.39706395e+00 -1.31544430e+00]
#  [-1.50652052e+00  9.82172869e-02 -1.28338910e+00 -1.31544430e+00]
#  [-1.02184904e+00  1.24920112e+00 -1.34022653e+00 -1.31544430e+00]
#  [-5.37177559e-01  1.93979142e+00 -1.16971425e+00 -1.05217993e+00]
#  [-1.50652052e+00  7.88807586e-01 -1.34022653e+00 -1.18381211e+00]
#  [-1.02184904e+00  7.88807586e-01 -1.28338910e+00 -1.31544430e+00]
#  [-1.74885626e+00 -3.62176246e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00  9.82172869e-02 -1.28338910e+00 -1.44707648e+00]
#  [-5.37177559e-01  1.47939788e+00 -1.28338910e+00 -1.31544430e+00]
#  [-1.26418478e+00  7.88807586e-01 -1.22655167e+00 -1.31544430e+00]
#  [-1.26418478e+00 -1.31979479e-01 -1.34022653e+00 -1.44707648e+00]
#  [-1.87002413e+00 -1.31979479e-01 -1.51073881e+00 -1.44707648e+00]
# ...

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler

data = load_iris()
scale = StandardScaler()

X_data = data.data
target = data.target

scaled_data = scale.fit_transform(X_data)
print(scaled_data)
# Out:
# [[-9.00681170e-01  1.01900435e+00 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00 -1.31979479e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.38535265e+00  3.28414053e-01 -1.39706395e+00 -1.31544430e+00]
#  [-1.50652052e+00  9.82172869e-02 -1.28338910e+00 -1.31544430e+00]
#  [-1.02184904e+00  1.24920112e+00 -1.34022653e+00 -1.31544430e+00]
#  [-5.37177559e-01  1.93979142e+00 -1.16971425e+00 -1.05217993e+00]
#  [-1.50652052e+00  7.88807586e-01 -1.34022653e+00 -1.18381211e+00]
#  [-1.02184904e+00  7.88807586e-01 -1.28338910e+00 -1.31544430e+00]
#  [-1.74885626e+00 -3.62176246e-01 -1.34022653e+00 -1.31544430e+00]
#  [-1.14301691e+00  9.82172869e-02 -1.28338910e+00 -1.44707648e+00]
#  [-5.37177559e-01  1.47939788e+00 -1.28338910e+00 -1.31544430e+00]
#  [-1.26418478e+00  7.88807586e-01 -1.22655167e+00 -1.31544430e+00]
#  [-1.26418478e+00 -1.31979479e-01 -1.34022653e+00 -1.44707648e+00]
#  [-1.87002413e+00 -1.31979479e-01 -1.51073881e+00 -1.44707648e+00]
# ...

# %%
pd.DataFrame(scaled_data)
# Out:
#             0         1         2         3
# 0   -0.900681  1.019004 -1.340227 -1.315444
# 1   -1.143017 -0.131979 -1.340227 -1.315444
# 2   -1.385353  0.328414 -1.397064 -1.315444
# 3   -1.506521  0.098217 -1.283389 -1.315444
# 4   -1.021849  1.249201 -1.340227 -1.315444
# ..        ...       ...       ...       ...
# 145  1.038005 -0.131979  0.819596  1.448832
# 146  0.553333 -1.282963  0.705921  0.922303
# 147  0.795669 -0.131979  0.819596  1.053935
# 148  0.432165  0.788808  0.933271  1.448832
# 149  0.068662 -0.131979  0.762758  0.790671
#
# [150 rows x 4 columns]

# %%
scaled_data
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
scaled_df = pd.DataFrame

# %%
scaled_df = pd.DataFrame(scaled_data)

# %%
X
# Out:
#       Age            Cabin Embarked      Fare  \
# 0    34.5  B57 B59 B63 B66        Q    7.8292
# 1    47.0              NaN        S    7.0000
# 2    62.0              NaN        Q    9.6875
# 3    27.0              NaN        S    8.6625
# 4    22.0              NaN        S   12.2875
# ..    ...              ...      ...       ...
# 413  30.0              NaN        S    8.0500
# 414  39.0             C105        C  108.9000
# 415  38.5              NaN        S    7.2500
# 416  30.0              NaN        S    8.0500
# 417   4.0              NaN        C   22.3583
#
#                                              Name  Parch  PassengerId  Pclass  \
# 0                                Kelly, Mr. James      0          892       3
# 1                Wilkes, Mrs. James (Ellen Needs)      0          893       3
# 2                       Myles, Mr. Thomas Francis      0          894       2
# 3                                Wirz, Mr. Albert      0          895       3
# ...

# %%
y
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 413   NaN
# 414   NaN
# 415   NaN
# 416   NaN
# 417   NaN
# Name: Survived, Length: 418, dtype: float64

# %%
y.shape
# Out:
# (418,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
X_train
# Out:
#       Age Cabin Embarked     Fare  \
# 317  19.0   NaN        S  10.5000
# 50   24.0   C31        S  60.0000
# 102  30.0   NaN        Q   7.7500
# 364  25.0   E50        C  55.4417
# 105  28.0   NaN        S  22.5250
# ..    ...   ...      ...      ...
# 234  39.0   C85        C  71.2833
# 205  30.0   NaN        C  25.7417
# 401  38.0   NaN        S  21.0000
# 48   60.0   D15        C  76.2917
# 43   30.0   NaN        S  13.0000
#
#                                                 Name  Parch  PassengerId  \
# 317                       Rogers, Mr. Reginald Harry      0         1209
# 50                          Smith, Mr. Lucien Philip      0          942
# 102                               Foley, Mr. William      0          994
# 364     Harder, Mrs. George Achilles (Dorothy Annan)      0         1256
# 105                        Holthen, Mr. Johan Martin      0          997
# ..                                               ...    ...          ...
# ...

# %%
y_train.shape, y_test.shape
# Out:
# ((334,), (84,))

# %%
y_train.values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %%
X.shape
# Out:
# (418, 13)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit
# Out:
# <bound method LogisticRegression.fit of LogisticRegression()>

# %%
model
# Out:
# LogisticRegression()

# %%
model.predict
# Out:
# <bound method LinearClassifierMixin.predict of LogisticRegression()>

# %%
y_test.values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan])

# %%
x_test.values
# Out:
# array([[48.0, 'B57 B59 B63 B66', 'C', ..., 'PC 17608', 'Mrs', 4],
#        [30.0, nan, 'S', ..., 'SOTON/O.Q. 3101314', 'Mr', 0],
#        [21.0, nan, 'S', ..., '345501', 'Mr', 0],
#        ...,
#        [30.0, nan, 'S', ..., '345498', 'Mr', 0],
#        [28.0, 'C23 C25 C27', 'S', ..., '19950', 'Miss', 5],
#        [55.0, 'C39', 'S', ..., '680', 'Mr', 0]], dtype=object)

# %%
from sklearn import neighbors, datasets
iris = datasets.load_iris()
X,y = iris.data, iris.target
knn = neighbors.KNeighborsClassifier(n_neighbors=1)
knn.fit(X,y)
print(iris.target_names[knn.predict([[3,5,4,2]])])
# Out:
# ['virginica']

# %%
from sklearn.linear_model import LinearRegression

X = 30 * np.random.random((20,1))

y = 0.5 * X + 1.0 + np.random.normal(size=X.shape)

model = LinearRegression()
model.fit(X,y)

X_new = np.linspace(0, 30, 100)
y_new = model.predict(X_new[:, np.newaxis])

# %%
from sklearn.datasets import load_digits
digits = load_digits()

# %%
print(model.predict)
# Out:
# <bound method LinearModel.predict of LinearRegression()>

# %%
model.predict
print(X_test)
# Out:
#        Age Cabin Embarked     Fare                            Name  Parch  \
# 135  24.00   NaN        S   7.8542       Carlsson, Mr. Carl Robert      0
# 398  22.00   NaN        S   7.7750  Larsson-Rondberg, Mr. Edvard A      0
# 71   21.00   NaN        S   7.8958              Minkoff, Mr. Lazar      0
# 36   22.00   NaN        S   8.0500             Roth, Miss. Sarah A      0
# 281   0.75   NaN        S  13.7750  Peacock, Master. Alfred Edward      1
# ..     ...   ...      ...      ...                             ...    ...
# 110  41.00   NaN        C  15.0458        Stanton, Mr. Samuel Ward      0
# 200  22.00   NaN        Q  15.5000              Murphy, Miss. Nora      0
# 403  17.00   NaN        S  47.1000          Carrau, Mr. Jose Pedro      0
# 293  53.00   A34        S  81.8583           Dodge, Dr. Washington      1
# 188  22.00   NaN        S  69.5500                 Sage, Miss. Ada      2
#
#      PassengerId  Pclass     Sex  SibSp              Ticket   Title  \
# ...

# %%
predicted_data = pd.DataFrame(y_test.values)

# %%
predicted_data
# Out:
#      0
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# ..  ..
# 79 NaN
# 80 NaN
# 81 NaN
# 82 NaN
# 83 NaN
#
# [84 rows x 1 columns]

# %%
predicted_data
# Out:
#      0
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
# ..  ..
# 79 NaN
# 80 NaN
# 81 NaN
# 82 NaN
# 83 NaN
#
# [84 rows x 1 columns]

# %%
predicted_data.reset_index()
# Out:
#     index   0
# 0       0 NaN
# 1       1 NaN
# 2       2 NaN
# 3       3 NaN
# 4       4 NaN
# ..    ...  ..
# 79     79 NaN
# 80     80 NaN
# 81     81 NaN
# 82     82 NaN
# 83     83 NaN
#
# [84 rows x 2 columns]

# %%
predicted_data.reset_index(inplace = True)

# %%
columns = ["Actual_Survived", "Predicted_survived"]
predicted_data.columns = columns

# %%
predicted_data
# Out:
#     Actual_Survived  Predicted_survived
# 0                 0                 NaN
# 1                 1                 NaN
# 2                 2                 NaN
# 3                 3                 NaN
# 4                 4                 NaN
# ..              ...                 ...
# 79               79                 NaN
# 80               80                 NaN
# 81               81                 NaN
# 82               82                 NaN
# 83               83                 NaN
#
# [84 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
acc_of_model = accuracy_score

# %%
print("The accuracy of the model is ", acc_of_model)
# Out:
# The accuracy of the model is  <function accuracy_score at 0x7fe5859f5310>

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# %%
svc.fit = svc

# %%
svc.fit
# Out:
# SVC()

# %%
print(accuracy_score)
# Out:
# <function accuracy_score at 0x7fe5859f5310>
